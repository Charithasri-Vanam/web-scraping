# %% [markdown]
# <a href="https://colab.research.google.com/github/Charithasri-Vanam/web-scraping/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import the python request library to query a website
import requests
#specify the url we want to scrape from
Link = "https://en.wikipedia.org/wiki/Forbes_India%27s_richest_Indian_by_year"
#convert the web page to text
Link_text = requests.get(Link).text
print(Link_text)
# Out:
# <!DOCTYPE html>
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-1 vector-feature-appearance-pinned-clientpref-1 vector-feature-night-mode-enabled skin-theme-clientpref-day vector-toc-available" lang="en" dir="ltr">
# <head>
# <meta charset="UTF-8">
# <title>Forbes India's richest Indian by year - Wikipedia</title>
# ...

# %%
#import BautifulSoup library to pull data out of HTML and XML files
from bs4 import BeautifulSoup
#to convert Link_text into a BeautifulSoup Object
soup = BeautifulSoup(Link_text, 'lxml')
print(soup)
# Out:
# <!DOCTYPE html>
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-1 vector-feature-appearance-pinned-clientpref-1 vector-feature-night-mode-enabled skin-theme-clientpref-day vector-toc-available" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Forbes India's richest Indian by year - Wikipedia</title>
# ...

# %%
#make the indentation proper
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-1 vector-feature-appearance-pinned-clientpref-1 vector-feature-night-mode-enabled skin-theme-clientpref-day vector-toc-available" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Forbes India's richest Indian by year - Wikipedia
#   </title>
#   <script>
# ...

# %%
#To take a look at the title of the web page
print(soup.title)
# Out:
# <title>Forbes India's richest Indian by year - Wikipedia</title>

# %%
#Only the string not the tags
print(soup.title.string)
# Out:
# Forbes India's richest Indian by year - Wikipedia

# %%
#First <a></a> tag
soup.a
# Out:
# <a class="mw-jump-link" href="#bodyContent">Jump to content</a>

# %%
#all the <a> </a> tags
soup.find_all('a')
# Out:
# [<a class="mw-jump-link" href="#bodyContent">Jump to content</a>,
#  <a accesskey="z" href="/wiki/Main_Page" title="Visit the main page [z]"><span>Main page</span></a>,
#  <a href="/wiki/Wikipedia:Contents" title="Guides to browsing Wikipedia"><span>Contents</span></a>,
#  <a href="/wiki/Portal:Current_events" title="Articles related to current events"><span>Current events</span></a>,
#  <a accesskey="x" href="/wiki/Special:Random" title="Visit a randomly selected article [x]"><span>Random article</span></a>,
#  <a href="/wiki/Wikipedia:About" title="Learn about Wikipedia and how it works"><span>About Wikipedia</span></a>,
#  <a href="//en.wikipedia.org/wiki/Wikipedia:Contact_us" title="How to contact Wikipedia"><span>Contact us</span></a>,
#  <a href="/wiki/Help:Contents" title="Guidance on how to use and edit Wikipedia"><span>Help</span></a>,
#  <a href="/wiki/Help:Introduction" title="Learn how to edit Wikipedia"><span>Learn to edit</span></a>,
# ...

# %%
#Fetch all the table tags
all_table = soup.find_all('table')
print(all_table)
# Out:
# [<table class="wikitable sortable">
# <tbody><tr>
# <th>Year
# </th>
# <th>Richest
# </th>
# <th>Net worth in US$
# </th>
# <th>Second richest
# </th>
# <th>Net worth in US$
# </th>
# <th>Source
# </th></tr>
# <tr>
# <td>2024
# </td>
# <td><a href="/wiki/Mukesh_Ambani" title="Mukesh Ambani">Mukesh Ambani</a>
# </td>
# <td>124 billion <span typeof="mw:File"><span title="Increase"><img alt="Increase" class="mw-file-element" data-file-height="300" data-file-width="300" decoding="async" height="11" src="//upload.wikimedia.org/wikipedia/commons/thumb/b/b0/Increase2.svg/11px-Increase2.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/b/b0/Increase2.svg/17px-Increase2.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/b/b0/Increase2.svg/22px-Increase2.svg.png 2x" width="11"/></span></span>
# </td>
# <td><a href="/wiki/Gautam_Adani" title="Gautam Adani">Gautam Adani</a>
# </td>
# ...

# %%
#fetch all the table tags with class name="wikitable sortable"
our_table = soup.find('table', class_= 'wikitable sortable')
print(our_table)
# Out:
# <table class="wikitable sortable">
# <tbody><tr>
# <th>Year
# </th>
# <th>Richest
# </th>
# <th>Net worth in US$
# </th>
# <th>Second richest
# </th>
# <th>Net worth in US$
# </th>
# <th>Source
# </th></tr>
# <tr>
# <td>2024
# </td>
# <td><a href="/wiki/Mukesh_Ambani" title="Mukesh Ambani">Mukesh Ambani</a>
# </td>
# <td>124 billion <span typeof="mw:File"><span title="Increase"><img alt="Increase" class="mw-file-element" data-file-height="300" data-file-width="300" decoding="async" height="11" src="//upload.wikimedia.org/wikipedia/commons/thumb/b/b0/Increase2.svg/11px-Increase2.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/b/b0/Increase2.svg/17px-Increase2.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/b/b0/Increase2.svg/22px-Increase2.svg.png 2x" width="11"/></span></span>
# </td>
# <td><a href="/wiki/Gautam_Adani" title="Gautam Adani">Gautam Adani</a>
# </td>
# ...

# %%
#In the table that we will fetch find the <a> </a>tags
table_links = our_table.find_all('a')
print(table_links)
# Out:
# [<a href="/wiki/Mukesh_Ambani" title="Mukesh Ambani">Mukesh Ambani</a>, <a href="/wiki/Gautam_Adani" title="Gautam Adani">Gautam Adani</a>, <a href="#cite_note-5"><span class="cite-bracket">[</span>5<span class="cite-bracket">]</span></a>, <a href="#cite_note-6"><span class="cite-bracket">[</span>6<span class="cite-bracket">]</span></a>, <a href="#cite_note-7"><span class="cite-bracket">[</span>7<span class="cite-bracket">]</span></a>, <a href="#cite_note-8"><span class="cite-bracket">[</span>8<span class="cite-bracket">]</span></a>, <a href="#cite_note-9"><span class="cite-bracket">[</span>9<span class="cite-bracket">]</span></a>, <a href="#cite_note-10"><span class="cite-bracket">[</span>10<span class="cite-bracket">]</span></a>, <a href="/wiki/Azim_Premji" title="Azim Premji">Azim Premji</a>, <a href="#cite_note-11"><span class="cite-bracket">[</span>11<span class="cite-bracket">]</span></a>, <a href="#cite_note-12"><span class="cite-bracket">[</span>12<span class="cite-bracket">]
# ...

# %%
#put the title into a list
billionaires = []
for links in table_links:
 billionaires.append(links.get('title'))
print(billionaires)
# Out:
# ['Mukesh Ambani', 'Gautam Adani', None, None, None, None, None, None, 'Azim Premji', None, None, 'Dilip Shanghvi', None, None, None, 'Lakshmi Mittal', None, None, None, None, None, None, None, None, None, None, 'Kumar Mangalam Birla', None, None, 'Dhirubhai Ambani', None, None, None, None, None, None]

# %%
#Convert the list into a dataframe
import pandas as pd
df = pd.DataFrame(billionaires)
print(df)
# Out:
#                        0
# 0          Mukesh Ambani
# 1           Gautam Adani
# 2                   None
# 3                   None
# 4                   None
# 5                   None
# 6                   None
# 7                   None
# 8            Azim Premji
# 9                   None
# 10                  None
# 11        Dilip Shanghvi
# 12                  None
# 13                  None
# 14                  None
# 15        Lakshmi Mittal
# 16                  None
# 17                  None
# 18                  None
# 19                  None
# 20                  None
# 21                  None
# 22                  None
# 23                  None
# 24                  None
# 25                  None
# 26  Kumar Mangalam Birla
# 27                  None
# 28                  None
# 29      Dhirubhai Ambani
# 30                  None
# 31                  None
# 32                  None
# 33                  None
# 34                  None
# 35                  None

# %%
#To save the data into an excel file
writer = pd.ExcelWriter('indian_billionaires.xlsx', engine='xlsxwriter')
df.to_excel(writer, sheet_name='List')
writer.save()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-28-7fdf3fe9f8fb> in <cell line: 2>()
#       1 #To save the data into an excel file
# ----> 2 writer = pd.ExcelWriter('indian_billionaires.xlsx', engine='xlsxwriter')
#       3 df.to_excel(writer, sheet_name='List')
#       4 writer.save()
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/excel/_xlsxwriter.py in __init__(self, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs, **kwargs)
#     196     ) -> None:
#     197         # Use the xlsxwriter module as the Excel writer.
# --> 198         from xlsxwriter import Workbook
#     199
#     200         engine_kwargs = combine_kwargs(engine_kwargs, kwargs)
#
# ModuleNotFoundError: No module named 'xlsxwriter'
#
# ---------------------------------------------------------------------------
# ...
